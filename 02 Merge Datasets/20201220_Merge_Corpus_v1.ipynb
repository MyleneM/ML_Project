# %% [markdown]
# # 20201220_Master_Corpus_II_v1

# %%
import pandas as pd
import numpy as np
import os
import re

# %%
list_file = os.listdir('../meta corpus I')
list_file2 = sorted(list_file)
list_file3 = [x for x in list_file2 if 'txt' in x]
print(list_file3)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-df2c0a32e90b> in <module>
# ----> 1 list_file = os.listdir('../meta corpus I')
#       2 list_file2 = sorted(list_file)
#       3 list_file3 = [x for x in list_file2 if 'txt' in x]
#       4 print(list_file3)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../meta corpus I'

# %%
list_file = os.listdir('Scrapped_Dataframes')
print(list_file)
# Out:
# ['Pocket_Size_Theatre.csv', 'The_Plays_The_Thing_UK.csv', 'A_Younger_Theatre_Off_West_End.csv', 'Everything_Theatre.csv', '.DS_Store', 'Ought_To_Be_Clowns.csv', 'The_Blog_Of_Theatre_Thing.xlsx', 'West_End_Whingers.csv', 'Monkey_Matters.csv', 'Lou_Review.csv', 'View_From_The_Cheap_Seat.csv', 'The_Exeunt.csv', 'A_Younger_Theatre_West_End.csv', 'Lou_Review.xlsx', 'West_End_Wilma.csv']

# %%
list_file2 = sorted(list_file)

# %%
list_file3 = [x for x in list_file2 if 'csv' in x]

# %%
list_file3
# Out:
# ['A_Younger_Theatre_Off_West_End.csv',
#  'A_Younger_Theatre_West_End.csv',
#  'Everything_Theatre.csv',
#  'Lou_Review.csv',
#  'Monkey_Matters.csv',
#  'Ought_To_Be_Clowns.csv',
#  'Pocket_Size_Theatre.csv',
#  'The_Exeunt.csv',
#  'The_Plays_The_Thing_UK.csv',
#  'View_From_The_Cheap_Seat.csv',
#  'West_End_Whingers.csv',
#  'West_End_Wilma.csv']

# %%
list_dataframe = ["df_" + x.split(".")[0] for x in list_file3]
list_dataframe
# Out:
# ['df_A_Younger_Theatre_Off_West_End',
#  'df_A_Younger_Theatre_West_End',
#  'df_Everything_Theatre',
#  'df_Lou_Review',
#  'df_Monkey_Matters',
#  'df_Ought_To_Be_Clowns',
#  'df_Pocket_Size_Theatre',
#  'df_The_Exeunt',
#  'df_The_Plays_The_Thing_UK',
#  'df_View_From_The_Cheap_Seat',
#  'df_West_End_Whingers',
#  'df_West_End_Wilma']

# %%
df_A_Younger_Theatre_Off_West_End = pd.read_csv("Scrapped_Dataframes/"+list_file3[0])
df_A_Younger_Theatre_Off_West_End = df_A_Younger_Theatre_Off_West_End.loc[:, ~df_A_Younger_Theatre_Off_West_End.columns.str.contains('^Unnamed')]
df_A_Younger_Theatre_Off_West_End.head(3)
# Out:
#            Newspaper        Date           Reviewer                 Title  \
# 0  A YOUNGER THEATER  11/12/2020  Jessica Handscomb       The Dumb Waiter
# 1  A YOUNGER THEATER  10/12/2020  Jessica Handscomb              Mr Stink
# 2  A YOUNGER THEATER  08/12/2020       Olivia Kiely  The Gruffalo’s Child
#
#                                       Place Rating  \
# 0  Hampstead Theatre" property="og:title"/>   ★★★★
# 1                       Chickenshed Theatre    ★★★
# 2                              Tall Stories    ★★★
#
#                                             Keywords  \
# 0  Alec Newman,Alice Hamilton,Harold Pinter,James...
# 1  Belinda McGuirk,Bethany Hamlin,Bradley Davis,C...
# 2  Alexandra Palace,Althea Burey,Andy Shaw,Axel S...
#
#                                               Review
# 0  \nI think it’s fair to say that 2020 has been ...
# 1  \nDavid Walliams is not my favourite children’...
# 2  \nIt is fair to say that I’m a bit older than ...

# %%
df_A_Younger_Theatre_West_End = pd.read_csv("Scrapped_Dataframes/"+list_file3[1])
df_A_Younger_Theatre_West_End = df_A_Younger_Theatre_West_End.loc[:, ~df_A_Younger_Theatre_West_End.columns.str.contains('^Unnamed')]
df_A_Younger_Theatre_West_End.head(3)
# Out:
#            Newspaper        Date           Reviewer             Title  \
# 0  A YOUNGER THEATER  13/11/2020    Samuel Nicholls   [Title of Show]
# 1  A YOUNGER THEATER  06/11/2020  Ryan Van Champion  Death of England
# 2  A YOUNGER THEATER  12/10/2020  Ryan Van Champion       The Odyssey
#
#                                                Place Rating  \
# 0  Lambert Jackson and The Coliseum Online" prope...    ★★★
# 1                                   National Theatre  ★★★★★
# 2                              Jermyn Street Theatre    ★★★
#
#                                             Keywords  \
# 0  Hunter Bell,Jeff Bowen,Jenna Russell,Josh Seym...
# 1  Benjamin Grant,black lives matter,BLM,Brexit,C...
# 2  Asha Kingsley,David Threlfall,Ellie Nunn,Emily...
#
#                                               Review
# 0  \nWhen Mel Brooks’ The Producers made the jump...
# 1  \nWith a second national lockdown looming, the...
# 2  \nThe renowned Jermyn Street Theatre – the Wes...

# %%
df_Everything_Theatre = pd.read_csv("Scrapped_Dataframes/"+list_file3[2])
df_Everything_Theatre = df_Everything_Theatre.loc[:, ~df_Everything_Theatre.columns.str.contains('^Unnamed')]
df_Everything_Theatre.head(3)
# Out:
#             Newspaper        Date          Reviewer  \
# 0  EVERYTHING THEATER  2020-12-07      Cat Leyland
# 1  EVERYTHING THEATER  2020-12-07   Kate Woolgrove
# 2  EVERYTHING THEATER  2020-12-06     Mary Pollard
#
#                                Title Author  \
# 0     : The Flying Lovers of Vitebsk    NaN
# 1  : Christmas Tales ‘Live On Stage’    NaN
# 2                  : The Crow’s Tale    NaN
#
#                                Place  Opening  Closing Director Rating  \
# 0   live stream from Bristol Old Vic      NaN      NaN      NaN   100%
# 1                        Chickenshed      NaN      NaN      NaN    60%
# 2               Puppet Theatre Barge      NaN      NaN      NaN    80%
#
#                                             Keywords  \
# 0  Audrey Brisson, Bristol Old Vic, Bristol theat...
# 1  Chickenshed, Children's Theatre, Christmas sho...
# 2  Bori Mező, family theatre, Jan Zalud, Josh Mid...
#
#                                               Review
# ...

# %%
df_Lou_Review = pd.read_excel("Scrapped_Dataframes/"+"Lou_Review.xlsx", encoding = "ISO-8859-1")
df_Lou_Review.head(3)
# Out:
#        The Theature               The Title of the play Author of the Review  \
# 0   Omnibus Theatre   The Importance of BeingEarnest \n          Louise Penn
# 1     Old Red Lion *    Nuclear War, Buried, Graceland           Louise Penn
# 2     Vault Festival                          Bin Juice          Louise Penn
#
#   Date of Publish of Reviews  \
# 0             March 17, 2020
# 1             March 14, 2020
# 2             March 14, 2020
#
#                                                 Text
# 0   Say It Again, Sorry? have put together a very...
# 1  Three plays by three different dramatists, bro...
# 2  Where:\nCavern at The Vaults, Leake Street Tun...

# %%
df_Monkey_Matters = pd.read_csv("Scrapped_Dataframes/"+list_file3[4])
df_Monkey_Matters.head(3)
# Out:
#                   Title of the play           Theatre Reviewer  \
# 0  The Browning Version/South Downs           Minerva   Shyama
# 1                A Clockwork Orange   Stratford East.   Shyama
# 2                            Decade    Commodity Quay   Shyama
#
#    Date of Publication                                         Categories  \
# 0  28th September 2011  David Hare,Nicholas Farrell,Rattigan,South Dow...
# 1  21st September 2011  A Clockwork Orange review,Ashley Hunter,Ed DuR...
# 2   8th September 2011  Decade Commodity Quay review,Decade review,Hea...
#
#                                                 Text
# 0  What better way to continue the celebration of...
# 1  Call of the wild\nStories about sociopaths don...
# 2  Ten years since 9/11. Ten years since Jihadi m...

# %%
df_Monkey_Matters["Title of the play"] = df_Monkey_Matters["Title of the play"].replace("Reviews","")
df_Monkey_Matters["Title of the play"] = df_Monkey_Matters["Title of the play"].replace("reviews","")
df_Monkey_Matters["Title of the play"] = df_Monkey_Matters["Title of the play"].replace("Review","")
df_Monkey_Matters["Title of the play"] = df_Monkey_Matters["Title of the play"].replace("review","")

# %%
df_Monkey_Matters["Categories"] = df_Monkey_Matters["Categories"].replace("Reviews","")
df_Monkey_Matters["Categories"] = df_Monkey_Matters["Categories"].replace("reviews","")
df_Monkey_Matters["Categories"] = df_Monkey_Matters["Categories"].replace("Review","")
df_Monkey_Matters["Categories"] = df_Monkey_Matters["Categories"].replace("review","")

# %%
df_Ought_To_Be_Clowns = pd.read_csv("Scrapped_Dataframes/"+list_file3[5])
df_Ought_To_Be_Clowns = df_Ought_To_Be_Clowns.loc[:, ~df_Ought_To_Be_Clowns.columns.str.contains('^Unnamed')]
df_Ought_To_Be_Clowns.head(3)
# Out:
#             Newspaper        Date Reviewer  \
# 0  OUGHT TO BE CLOWNS  09/12/2020      Ian
# 1  OUGHT TO BE CLOWNS         NaN      Ian
# 2  OUGHT TO BE CLOWNS  08/12/2020      Ian
#
#                                       Title Theatre  \
# 0  Unlimited: The Songs of Stephen Schwartz     NaN
# 1                             On Cloud Nine     NaN
# 2                   The Fabulist Fox Sister     NaN
#
#                                               Review
# 0  “Out of our night of struggle\nCan we see a ra...
# 1  “Apparently in London everything is possible”\...
# 2  “Tonight is going to be different”\nWith music...

# %%
df_Pocket_Size_Theatre = pd.read_csv("Scrapped_Dataframes/"+list_file3[6])
df_Pocket_Size_Theatre = df_Pocket_Size_Theatre.loc[:, ~df_Pocket_Size_Theatre.columns.str.contains('^Unnamed')]
df_Pocket_Size_Theatre.head(3)
# Out:
#              Newspaper        Date    Reviewer             Title  \
# 0  Pocket Size Theatre  26/10/2020  Nick Wayne        Lone Flyer
# 1  Pocket Size Theatre  17/10/2020  Mark Swale  Buyer and Cellar
# 2  Pocket Size Theatre  26/09/2020  Nick Wayne         Bloodshot
#
#                   Theatre Rating  \
# 0  the Watermill, Newbury   ★★★★
# 1         Above the Stag    ★★★★
# 2  the Watermill Theatre   ★★★★★
#
#                                               Review
# 0  The Watermill continues its indoor reopening s...
# 1  Originally performed by Michael Urie, Buyer an...
# 2  After a very successful outdoor summer season ...

# %%
df_The_Blog_Of_Theatre_Thing = pd.read_excel("Scrapped_Dataframes/The_Blog_Of_Theatre_Thing.xlsx")
df_The_Blog_Of_Theatre_Thing.head(3)
# Out:
#                                    Title of the Play         Theatre   \
# 0  The Legend of Moby Dick Whittington (online re...    online review
# 1                            Wh a Carve Up! (online)    online review
# 2                                  Macbeth (online)    Belfast Intern
#
#   Date of Publication                Categories  \
# 0    December 1, 2020   ONLINE THEATRE, REVIEWS
# 1    November 1, 2020   ONLINE THEATRE, REVIEWS
# 2    October 17, 2020                   REVIEWS
#
#                                             Keywords  \
# 0   ADVENTURE, CHRISTMAS, COMEDY, DICK WHITTINGTO...
# 1                                               None
# 2                                               None
#
#                                                 Text
# 0  Since 2014, comedy trio The Sleeping Trees hav...
# 1  As an anxious, frustrated and oh so tired nati...
# 2  Let's face it, one of the few positives of loc...

# %%
df_The_Exeunt = pd.read_csv("Scrapped_Dataframes/"+list_file3[7])
df_The_Exeunt = df_The_Exeunt.loc[:, ~df_The_Exeunt.columns.str.contains('^Unnamed')]
df_The_Exeunt.head(3)
# Out:
#          Newspaper              Date       Reviewer  \
# 0  EXEUNT MAGAZINE   7 December 2020  Lily Levinson
# 1  EXEUNT MAGAZINE  30 November 2020    Naomi Obeng
# 2  EXEUNT MAGAZINE    2 October 2020  Alice Saville
#
#                                                Title  \
# 0  Review: The Fabulist Fox Sister, Southwark Pla...
# 1                               The Kids Are Alright
# 2                                    Sunnymead Court
#
#                              Author                             Place  \
# 0   Michael Conley and Luke Bateman                               NaN
# 1                     Lee Mattinson  Evelyn Estate, Deptford (online)
# 2                    Gemma Lawrence             Tristan Bates Theatre
#
#          Opening       Closing        Director  \
# 0            4th  5th December    ALP Musicals
# 1   27 November     2 December    Jen Malarkey
# 2            NaN           NaN   James Hillier
#
#                                               Review
# ...

# %%
df_The_Plays_The_Thing_UK = pd.read_csv("Scrapped_Dataframes/"+list_file3[8])
df_The_Plays_The_Thing_UK = df_The_Plays_The_Thing_UK.loc[:, ~df_The_Plays_The_Thing_UK.columns.str.contains('^Unnamed')]
df_The_Plays_The_Thing_UK.head(3)
# Out:
#                 Title of the Play          Theatre          Reviewer  \
# 0  When the Sea Swallows Us Whole    VAULTFestival   by Dora Bodrogi
# 1                     On Arriving    VAULTFestival    by Emma Lamond
# 2                          Gorgon   VAULT Festival  by Verity Sharpe
#
#   Date of the Review    Reviewer.1  \
# 0          06-Feb-20  laurakressly
# 1          07-Feb-20  laurakressly
# 2          10-Feb-20  laurakressly
#
#                                             Keywords  \
# 0  climate change,family,friendship,growing up,LG...
# 1  immigration,new writing,political issues,refug...
# 2  foley,horror,new writing,review,sound,storytel...
#
#                                                 Text
# 0  by Dora Bodrogi\nClimate, sexuality, religion,...
# 1  by Emma Lamond\nThis play is a confronting and...
# 2  by Verity Sharpe\nThis is a spectacularly bril...

# %%
df_The_Plays_The_Thing_UK['Theatre'] = df_The_Plays_The_Thing_UK['Theatre'].replace("VAULTFestival","VAULT Festival")
df_The_Plays_The_Thing_UK['Theatre'] = df_The_Plays_The_Thing_UK['Theatre'].replace(" VAULTFestival","VAULT Festival")

df_The_Plays_The_Thing_UK['Reviewer'] = df_The_Plays_The_Thing_UK['Reviewer'].replace("by ","")

# %%
for i in range(0,len(df_The_Plays_The_Thing_UK['Theatre'])):
    if len(re.findall(r'[A-Z]',df_The_Plays_The_Thing_UK['Theatre'][i])) == 2:
        list_word = re.sub( r"([A-Z])", r" \1", df_The_Plays_The_Thing_UK['Theatre'][i]).split()
        df_The_Plays_The_Thing_UK['Theatre'][i] = list_word[0]+" "+list_word[1]

# %%
for i in range(0,len(df_The_Plays_The_Thing_UK['Text'])):
    if "\n" in str(df_The_Plays_The_Thing_UK['Text'][i]):
        df_The_Plays_The_Thing_UK['Text'][i] = df_The_Plays_The_Thing_UK['Text'][i].split("\n")[1]
    else:
        df_The_Plays_The_Thing_UK['Text'][i] =df_The_Plays_The_Thing_UK['Text'][i]

# %%
for i in range(0,len(df_The_Plays_The_Thing_UK["Text"])):
    df_The_Plays_The_Thing_UK["Text"][i] = re.sub(r'[^\x00-\x7f]',r' ',str(df_The_Plays_The_Thing_UK["Text"][i]))
df_The_Plays_The_Thing_UK["Text"] = df_The_Plays_The_Thing_UK["Text"].replace("  "," ")

# %%
df_View_From_The_Cheap_Seat = pd.read_csv("Scrapped_Dataframes/"+list_file3[9])
df_View_From_The_Cheap_Seat = df_View_From_The_Cheap_Seat.loc[:, ~df_View_From_The_Cheap_Seat.columns.str.contains('^Unnamed')]
df_View_From_The_Cheap_Seat.head(3)
# Out:
#      Title of the Play        Theature of the Play    Published Date  \
# 0            Stay Safe                    Whatsapp  October 30, 2020
# 1  Next Thing You Know   Garden Theatre @Eagle Pub  October 27, 2020
# 2              Eye Say                     Eye Say  October 18, 2020
#
#          Author by                                               Text
# 0   Shanine Salmon  Whatspp? Yes, New Perspective's haunting new p...
# 1  naomiwesterman1  Forgive me for taking the scenic route to star...
# 2       Alex Finch  Eye Say, Eye Say, Eye Say' brought together th...

# %%
for i in range(0,len(df_View_From_The_Cheap_Seat["Text"])):
    df_View_From_The_Cheap_Seat["Text"][i] = re.sub(r'[^\x00-\x7f]',r' ',str(df_View_From_The_Cheap_Seat["Text"][i]))
df_View_From_The_Cheap_Seat["Text"] = df_View_From_The_Cheap_Seat["Text"].replace("  "," ")

# %%
df_West_End_Whingers = pd.read_csv("Scrapped_Dataframes/"+list_file3[10])
df_West_End_Whingers = df_West_End_Whingers.loc[:, ~df_West_End_Whingers.columns.str.contains('^Unnamed')]
df_West_End_Whingers.head(3)
# Out:
#            Newspaper        Date Reviewer  \
# 0  West End Winghers  30/04/2012     Phil
# 1  West End Winghers  09/11/2012     Phil
# 2  West End Winghers  18/05/2008     Phil
#
#                                      Title                Theatre Rating  \
# 0       South Downs / The Browning Version  Harold Pinter Theatre  ★★★★★
# 1                               Steel Pier          Union Theatre    ★★★
# 2  That Face at the Duke of York’s Theatre                    NaN    NaN
#
#                                               Review
# 0  \nOne Man’s Two Guvnors may be another man’s p...
# 1  \nSPOILERS. Imagine They Shoot Horses, Don’t T...
# 2  The Whingers are feeling a tad existential tod...

# %%
list_review_winghers = []

for i in range(0, len(df_West_End_Whingers['Review'])):
    if 'Footnotes' in str(df_West_End_Whingers['Review'][i]):
        list_review_winghers.append(df_West_End_Whingers['Review'][i].split('Footnotes')[0])
    elif 'This entry was posted on' in str(df_West_End_Whingers['Review'][i]):
        list_review_winghers.append(df_West_End_Whingers['Review'][i].split('This entry was posted on')[0])
    elif 'For further theatre' in str(df_West_End_Whingers['Review'][i]):
        list_review_winghers.append(df_West_End_Whingers['Review'][i].split('For further theatre')[0])
    elif 'Footnote' in str(df_West_End_Whingers['Review'][i]):
        list_review_winghers.append(df_West_End_Whingers['Review'][i].split('Footnote')[0])
    else:
        list_review_winghers.append(df_West_End_Whingers['Review'][i])

# %%
df_West_End_Whingers['Review'] = list_review_winghers
df_West_End_Whingers.head(3)
# Out:
#            Newspaper        Date Reviewer  \
# 0  West End Winghers  30/04/2012     Phil
# 1  West End Winghers  09/11/2012     Phil
# 2  West End Winghers  18/05/2008     Phil
#
#                                      Title                Theatre Rating  \
# 0       South Downs / The Browning Version  Harold Pinter Theatre  ★★★★★
# 1                               Steel Pier          Union Theatre    ★★★
# 2  That Face at the Duke of York’s Theatre                    NaN    NaN
#
#                                               Review
# 0  \nOne Man’s Two Guvnors may be another man’s p...
# 1  \nSPOILERS. Imagine They Shoot Horses, Don’t T...
# 2  The Whingers are feeling a tad existential tod...

# %%
df_West_End_Whingers.to_excel("hello.xlsx")

# %%
df_West_End_Wilma = pd.read_csv("Scrapped_Dataframes/"+list_file3[11])
df_West_End_Wilma = df_West_End_Wilma.loc[:, ~df_West_End_Wilma.columns.str.contains('^Unnamed')]
df_West_End_Wilma.head(3)
# Out:
#         Newspaper        Date         Reviewer  \
# 0  WEST END WILMA  2020-03-26       Emma Heath
# 1  WEST END WILMA  2020-03-12   West End Wilma
# 2  WEST END WILMA  2020-02-24       Emma Heath
#
#                                 Title                          Place  \
# 0                    LOVE, LOVE, LOVE          the Lyric Hammersmith
# 1  Irish Play ON BLUEBERRY HILL opens    Trafalgar Studios exploring
# 2                  La Cage aux Folles  Park Theatre - West End Wilma
#
#                                               Rating  \
# 0                                                 ★★
# 1  ★★★★\nReviewed by West End Wilma\nPhoto: Marc ...
# 2                                                ★★★
#
#                                               Review
# 0  Written by Mike Bartlett, Love, Love, Love ser...
# 1  \nSebastian Barry‘s 2017 production of On Blue...
# 2  Too much farce and not enough affection in thi...

# %%
df_West_End_Wilma['Review'] = df_West_End_Wilma['Review'].replace('<p>','')
df_West_End_Wilma['Review'] = df_West_End_Wilma['Review'].replace('</p>','')
df_West_End_Wilma['Review'] = df_West_End_Wilma['Review'].replace('<br>','')
df_West_End_Wilma['Review'] = df_West_End_Wilma['Review'].replace('</br>','')
df_West_End_Wilma['Review'] = df_West_End_Wilma['Review'].replace('<strong>','')
df_West_End_Wilma['Review'] = df_West_End_Wilma['Review'].replace('</strong>','')
df_West_End_Wilma['Review'] = df_West_End_Wilma['Review'].replace('<span>','')
df_West_End_Wilma['Review'] = df_West_End_Wilma['Review'].replace('</span>','')

# %% [markdown]
# ## III) Merge

# %%
df_A_Younger_Theatre_Off_West_End_2 = df_A_Younger_Theatre_Off_West_End.copy()
df_A_Younger_Theatre_West_End_2 = df_A_Younger_Theatre_West_End.copy()
df_Everything_Theatre_2 = df_Everything_Theatre.copy()
df_Lou_Review_2 = df_Lou_Review.copy()
df_Monkey_Matters_2 = df_Monkey_Matters.copy()
df_Ought_To_Be_Clowns_2 = df_Ought_To_Be_Clowns.copy()
df_Pocket_Size_Theatre_2 = df_Pocket_Size_Theatre.copy()
df_The_Blog_Of_Theatre_Thing_2 = df_The_Blog_Of_Theatre_Thing.copy()
df_The_Exeunt_2 = df_The_Exeunt.copy()
df_The_Plays_The_Thing_UK_2 = df_The_Plays_The_Thing_UK.copy()
df_View_From_The_Cheap_Seat_2 = df_View_From_The_Cheap_Seat.copy()
df_West_End_Whingers_2 = df_West_End_Whingers.copy()
df_West_End_Wilma_2 = df_West_End_Wilma.copy()

# %%
df_Lou_Review.head(3)
# Out:
#     Newspaper      The Theature               The Title of the play  \
# 0  Lou Review   Omnibus Theatre   The Importance of BeingEarnest \n
# 1  Lou Review     Old Red Lion *    Nuclear War, Buried, Graceland
# 2  Lou Review     Vault Festival                          Bin Juice
#
#   Author of the Review Date of Publish of Reviews  \
# 0          Louise Penn             March 17, 2020
# 1          Louise Penn             March 14, 2020
# 2          Louise Penn             March 14, 2020
#
#                                                 Text
# 0   Say It Again, Sorry? have put together a very...
# 1  Three plays by three different dramatists, bro...
# 2  Where:\nCavern at The Vaults, Leake Street Tun...

# %%
df_Lou_Review_2.insert(loc=0, column='Newspaper', value=["Lou Review"] * df_Lou_Review_2.shape[0])
df_Monkey_Matters_2.insert(loc=0, column='Newspaper', value=["Monkey Matters"] * df_Monkey_Matters_2.shape[0])
df_The_Blog_Of_Theatre_Thing_2.insert(loc=0, column='Newspaper', value=["The Blog Of Theatre Thing"] * df_The_Blog_Of_Theatre_Thing_2.shape[0])
df_The_Plays_The_Thing_UK_2.insert(loc=0, column='Newspaper', value=["The Plays The Thing UK"] * df_The_Plays_The_Thing_UK_2.shape[0])
df_View_From_The_Cheap_Seat_2.insert(loc=0, column='Newspaper', value=["View From The Cheap Seat"] * df_View_From_The_Cheap_Seat_2.shape[0])

# %%
# Review
df_Lou_Review_2 =  df_Lou_Review_2.rename({'Text': 'Review'}, axis=1)
df_Monkey_Matters_2 =  df_Monkey_Matters_2.rename({'Text': 'Review'}, axis=1)
df_The_Blog_Of_Theatre_Thing_2 =  df_The_Blog_Of_Theatre_Thing_2.rename({'Text': 'Review'}, axis=1)
df_The_Plays_The_Thing_UK_2 =  df_The_Plays_The_Thing_UK_2.rename({'Text': 'Review'}, axis=1)
df_View_From_The_Cheap_Seat_2 =  df_View_From_The_Cheap_Seat_2.rename({'Text': 'Review'}, axis=1)

# %%
# Title
df_Lou_Review_2 =  df_Lou_Review_2.rename({'The Title of the play': 'Title'}, axis=1)
df_Monkey_Matters_2 =  df_Monkey_Matters_2.rename({'Title of the play': 'Title'}, axis=1)
df_The_Blog_Of_Theatre_Thing_2 =  df_The_Blog_Of_Theatre_Thing_2.rename({'Title of the Play': 'Title'}, axis=1)
df_The_Plays_The_Thing_UK_2 =  df_The_Plays_The_Thing_UK_2.rename({'Title of the Play': 'Title'}, axis=1)
df_View_From_The_Cheap_Seat_2 =  df_View_From_The_Cheap_Seat_2.rename({'Title of the Play': 'Title'}, axis=1)

# %%
# Date
df_Lou_Review_2 =  df_Lou_Review_2.rename({'Date of Publish of Reviews': 'Date'}, axis=1)
df_Monkey_Matters_2 =  df_Monkey_Matters_2.rename({'Date of Publication': 'Date'}, axis=1)
df_The_Blog_Of_Theatre_Thing_2 =  df_The_Blog_Of_Theatre_Thing_2.rename({'Date of Publication': 'Date'}, axis=1)
df_The_Plays_The_Thing_UK_2 =  df_The_Plays_The_Thing_UK_2.rename({'Date of the Review': 'Date'}, axis=1)
df_View_From_The_Cheap_Seat_2 =  df_View_From_The_Cheap_Seat_2.rename({'Published Date': 'Date'}, axis=1)

# %%
# Theatre 
df_A_Younger_Theatre_Off_West_End_2 =  df_A_Younger_Theatre_Off_West_End_2.rename({'Place': 'Theatre'}, axis=1)
df_A_Younger_Theatre_West_End_2 =  df_A_Younger_Theatre_West_End_2.rename({'Place': 'Theatre'}, axis=1)
df_Everything_Theatre_2 =  df_Everything_Theatre_2.rename({'Place': 'Theatre'}, axis=1)
df_Lou_Review_2 =  df_Lou_Review_2.rename({'The Theature ': 'Theatre'}, axis=1)
df_The_Exeunt_2 =  df_The_Exeunt_2.rename({'Place': 'Theatre'}, axis=1)
df_View_From_The_Cheap_Seat_2 =  df_View_From_The_Cheap_Seat_2.rename({'Theature of the Play': 'Theatre'}, axis=1)
df_West_End_Wilma_2 =  df_West_End_Wilma_2.rename({'Place': 'Theatre'}, axis=1)

# %%
# Reviewer

df_Lou_Review_2 =  df_Lou_Review_2.rename({'Author of the Review': 'Reviewer'}, axis=1)
df_View_From_The_Cheap_Seat_2 =  df_View_From_The_Cheap_Seat_2.rename({'Author by': 'Reviewer'}, axis=1)

# %%
type(df_A_Younger_Theatre_Off_West_End_2['Date'][0])
# Out:
# str

# %%
df_A_Younger_Theatre_Off_West_End_2['Date'] = pd.to_datetime(df_A_Younger_Theatre_Off_West_End_2['Date'])
df_A_Younger_Theatre_Off_West_End_2['Date'] = pd.to_datetime(df_A_Younger_Theatre_Off_West_End_2["Date"].dt.strftime('%Y-%m-%d'))
df_A_Younger_Theatre_Off_West_End_2.head(3)
# Out:
#            Newspaper       Date           Reviewer                 Title  \
# 0  A YOUNGER THEATER 2020-11-12  Jessica Handscomb       The Dumb Waiter
# 1  A YOUNGER THEATER 2020-10-12  Jessica Handscomb              Mr Stink
# 2  A YOUNGER THEATER 2020-08-12       Olivia Kiely  The Gruffalo’s Child
#
#                                     Theatre Rating  \
# 0  Hampstead Theatre" property="og:title"/>   ★★★★
# 1                       Chickenshed Theatre    ★★★
# 2                              Tall Stories    ★★★
#
#                                             Keywords  \
# 0  Alec Newman,Alice Hamilton,Harold Pinter,James...
# 1  Belinda McGuirk,Bethany Hamlin,Bradley Davis,C...
# 2  Alexandra Palace,Althea Burey,Andy Shaw,Axel S...
#
#                                               Review
# 0  \nI think it’s fair to say that 2020 has been ...
# 1  \nDavid Walliams is not my favourite children’...
# 2  \nIt is fair to say that I’m a bit older than ...

# %%
df_A_Younger_Theatre_West_End_2['Date'] = pd.to_datetime(df_A_Younger_Theatre_West_End_2['Date'])
df_A_Younger_Theatre_West_End_2['Date'] = pd.to_datetime(df_A_Younger_Theatre_West_End_2["Date"].dt.strftime('%Y-%m-%d'))
df_A_Younger_Theatre_West_End_2.head(3)
# Out:
#            Newspaper       Date           Reviewer             Title  \
# 0  A YOUNGER THEATER 2020-11-13    Samuel Nicholls   [Title of Show]
# 1  A YOUNGER THEATER 2020-06-11  Ryan Van Champion  Death of England
# 2  A YOUNGER THEATER 2020-12-10  Ryan Van Champion       The Odyssey
#
#                                              Theatre Rating  \
# 0  Lambert Jackson and The Coliseum Online" prope...    ★★★
# 1                                   National Theatre  ★★★★★
# 2                              Jermyn Street Theatre    ★★★
#
#                                             Keywords  \
# 0  Hunter Bell,Jeff Bowen,Jenna Russell,Josh Seym...
# 1  Benjamin Grant,black lives matter,BLM,Brexit,C...
# 2  Asha Kingsley,David Threlfall,Ellie Nunn,Emily...
#
#                                               Review
# 0  \nWhen Mel Brooks’ The Producers made the jump...
# 1  \nWith a second national lockdown looming, the...
# 2  \nThe renowned Jermyn Street Theatre – the Wes...

# %%
df_Everything_Theatre_2['Date'] = pd.to_datetime(df_Everything_Theatre_2['Date'])
df_Everything_Theatre_2['Date'] = pd.to_datetime(df_Everything_Theatre_2["Date"].dt.strftime('%Y-%m-%d'))
df_Everything_Theatre_2.head(3)
# Out:
#             Newspaper       Date          Reviewer  \
# 0  EVERYTHING THEATER 2020-12-07      Cat Leyland
# 1  EVERYTHING THEATER 2020-12-07   Kate Woolgrove
# 2  EVERYTHING THEATER 2020-12-06     Mary Pollard
#
#                                Title Author  \
# 0     : The Flying Lovers of Vitebsk    NaN
# 1  : Christmas Tales ‘Live On Stage’    NaN
# 2                  : The Crow’s Tale    NaN
#
#                              Theatre  Opening  Closing Director Rating  \
# 0   live stream from Bristol Old Vic      NaN      NaN      NaN   100%
# 1                        Chickenshed      NaN      NaN      NaN    60%
# 2               Puppet Theatre Barge      NaN      NaN      NaN    80%
#
#                                             Keywords  \
# 0  Audrey Brisson, Bristol Old Vic, Bristol theat...
# 1  Chickenshed, Children's Theatre, Christmas sho...
# 2  Bori Mező, family theatre, Jan Zalud, Josh Mid...
#
#                                               Review
# ...

# %%
df_Everything_Theatre_2['Title'] = df_Everything_Theatre_2['Title'].replace(":","")
df_Everything_Theatre_2['Rating'] = df_Everything_Theatre_2['Rating'].replace("100%","★★★★★")
df_Everything_Theatre_2['Rating'] = df_Everything_Theatre_2['Rating'].replace("60%","★★★")
df_Everything_Theatre_2['Rating'] = df_Everything_Theatre_2['Rating'].replace("80%","★★★★")
df_Everything_Theatre_2['Rating'] = df_Everything_Theatre_2['Rating'].replace("None","")
df_Everything_Theatre_2['Rating'] = df_Everything_Theatre_2['Rating'].replace("40%","★★")
df_Everything_Theatre_2['Rating'] = df_Everything_Theatre_2['Rating'].replace("%","")
df_Everything_Theatre_2['Rating'] = df_Everything_Theatre_2['Rating'].replace("79%","★★★★")
df_Everything_Theatre_2['Rating'] = df_Everything_Theatre_2['Rating'].replace("61%","★★★")
df_Everything_Theatre_2['Rating'] = df_Everything_Theatre_2['Rating'].replace("20%","★")
df_Everything_Theatre_2['Rating'] = df_Everything_Theatre_2['Rating'].replace("59%","★★★")
df_Everything_Theatre_2['Rating'] = df_Everything_Theatre_2['Rating'].replace("41%","★★")
df_Everything_Theatre_2['Rating'] = df_Everything_Theatre_2['Rating'].replace("30%","★★")
df_Everything_Theatre_2['Rating'] = df_Everything_Theatre_2['Rating'].replace("39%","★★")

# %%
df_Everything_Theatre_2['Title'] = df_Everything_Theatre_2['Title'].replace(": ","")

# %%
for i in range(0,len(df_Everything_Theatre_2['Title'])):
    df_Everything_Theatre_2['Title'][i] = df_Everything_Theatre_2['Title'][i].replace(": ","")
# Out:
# /Users/gaetanbrison/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_Everything_Theatre_2.head(3)
# Out:
#             Newspaper        Date          Reviewer  \
# 0  EVERYTHING THEATER  2020-12-07      Cat Leyland
# 1  EVERYTHING THEATER  2020-12-07   Kate Woolgrove
# 2  EVERYTHING THEATER  2020-12-06     Mary Pollard
#
#                              Title Author                            Theatre  \
# 0     The Flying Lovers of Vitebsk    NaN   live stream from Bristol Old Vic
# 1  Christmas Tales ‘Live On Stage’    NaN                        Chickenshed
# 2                  The Crow’s Tale    NaN               Puppet Theatre Barge
#
#    Opening  Closing Director Rating  \
# 0      NaN      NaN      NaN  ★★★★★
# 1      NaN      NaN      NaN    ★★★
# 2      NaN      NaN      NaN   ★★★★
#
#                                             Keywords  \
# 0  Audrey Brisson, Bristol Old Vic, Bristol theat...
# 1  Chickenshed, Children's Theatre, Christmas sho...
# 2  Bori Mező, family theatre, Jan Zalud, Josh Mid...
#
#                                               Review
# ...

# %%
df_Lou_Review_2['Date'] = pd.to_datetime(df_Lou_Review_2['Date'])
df_Lou_Review_2['Date'] = pd.to_datetime(df_Lou_Review_2["Date"].dt.strftime('%Y-%m-%d'))
df_Lou_Review_2.head(3)
# Out:
#     Newspaper            Theatre                              Title  \
# 0  Lou Review   Omnibus Theatre   The Importance of BeingEarnest \n
# 1  Lou Review     Old Red Lion *    Nuclear War, Buried, Graceland
# 2  Lou Review     Vault Festival                          Bin Juice
#
#       Reviewer       Date                                             Review
# 0  Louise Penn 2020-03-17   Say It Again, Sorry? have put together a very...
# 1  Louise Penn 2020-03-14  Three plays by three different dramatists, bro...
# 2  Louise Penn 2020-03-14  Where:\nCavern at The Vaults, Leake Street Tun...

# %%
df_Ought_To_Be_Clowns_2['Date'] = pd.to_datetime(df_Ought_To_Be_Clowns_2['Date'])
df_Ought_To_Be_Clowns_2['Date'] = pd.to_datetime(df_Ought_To_Be_Clowns_2["Date"].dt.strftime('%Y-%m-%d'))
df_Ought_To_Be_Clowns_2.head(3)
# Out:
#             Newspaper       Date Reviewer  \
# 0  OUGHT TO BE CLOWNS 2020-09-12      Ian
# 1  OUGHT TO BE CLOWNS        NaT      Ian
# 2  OUGHT TO BE CLOWNS 2020-08-12      Ian
#
#                                       Title Theatre  \
# 0  Unlimited: The Songs of Stephen Schwartz     NaN
# 1                             On Cloud Nine     NaN
# 2                   The Fabulist Fox Sister     NaN
#
#                                               Review
# 0  “Out of our night of struggle\nCan we see a ra...
# 1  “Apparently in London everything is possible”\...
# 2  “Tonight is going to be different”\nWith music...

# %%
df_Pocket_Size_Theatre_2['Date'] = pd.to_datetime(df_Pocket_Size_Theatre_2['Date'])
df_Pocket_Size_Theatre_2['Date'] = pd.to_datetime(df_Pocket_Size_Theatre_2["Date"].dt.strftime('%Y-%m-%d'))
df_Pocket_Size_Theatre_2.head(3)
# Out:
#              Newspaper       Date    Reviewer             Title  \
# 0  Pocket Size Theatre 2020-10-26  Nick Wayne        Lone Flyer
# 1  Pocket Size Theatre 2020-10-17  Mark Swale  Buyer and Cellar
# 2  Pocket Size Theatre 2020-09-26  Nick Wayne         Bloodshot
#
#                   Theatre Rating  \
# 0  the Watermill, Newbury   ★★★★
# 1         Above the Stag    ★★★★
# 2  the Watermill Theatre   ★★★★★
#
#                                               Review
# 0  The Watermill continues its indoor reopening s...
# 1  Originally performed by Michael Urie, Buyer an...
# 2  After a very successful outdoor summer season ...

# %%
df_The_Blog_Of_Theatre_Thing_2['Date'] = pd.to_datetime(df_The_Blog_Of_Theatre_Thing_2['Date'])
df_The_Blog_Of_Theatre_Thing_2['Date'] = pd.to_datetime(df_The_Blog_Of_Theatre_Thing_2["Date"].dt.strftime('%Y-%m-%d'))
df_The_Blog_Of_Theatre_Thing_2.head(3)
# Out:
#                    Newspaper  \
# 0  The Blog Of Theatre Thing
# 1  The Blog Of Theatre Thing
# 2  The Blog Of Theatre Thing
#
#                                                Title         Theatre   \
# 0  The Legend of Moby Dick Whittington (online re...    online review
# 1                            Wh a Carve Up! (online)    online review
# 2                                  Macbeth (online)    Belfast Intern
#
#         Date                Categories  \
# 0 2020-12-01   ONLINE THEATRE, REVIEWS
# 1 2020-11-01   ONLINE THEATRE, REVIEWS
# 2 2020-10-17                   REVIEWS
#
#                                             Keywords  \
# 0   ADVENTURE, CHRISTMAS, COMEDY, DICK WHITTINGTO...
# 1                                               None
# 2                                               None
#
#                                               Review
# 0  Since 2014, comedy trio The Sleeping Trees hav...
# 1  As an anxious, frustrated and oh so tired nati...
# ...

# %%
df_The_Exeunt_2['Date'] = pd.to_datetime(df_The_Exeunt_2['Date'])
df_The_Exeunt_2['Date'] = pd.to_datetime(df_The_Exeunt_2["Date"].dt.strftime('%Y-%m-%d'))
df_The_Exeunt_2.head(3)
# Out:
#          Newspaper       Date       Reviewer  \
# 0  EXEUNT MAGAZINE 2020-12-07  Lily Levinson
# 1  EXEUNT MAGAZINE 2020-11-30    Naomi Obeng
# 2  EXEUNT MAGAZINE 2020-10-02  Alice Saville
#
#                                                Title  \
# 0  Review: The Fabulist Fox Sister, Southwark Pla...
# 1                               The Kids Are Alright
# 2                                    Sunnymead Court
#
#                              Author                           Theatre  \
# 0   Michael Conley and Luke Bateman                               NaN
# 1                     Lee Mattinson  Evelyn Estate, Deptford (online)
# 2                    Gemma Lawrence             Tristan Bates Theatre
#
#          Opening       Closing        Director  \
# 0            4th  5th December    ALP Musicals
# 1   27 November     2 December    Jen Malarkey
# 2            NaN           NaN   James Hillier
#
#                                               Review
# ...

# %%
for i in range(0,len(df_The_Plays_The_Thing_UK_2['Date'])):
    if "of" in str(df_The_Plays_The_Thing_UK_2['Date'][i]):
        df_The_Plays_The_Thing_UK_2['Date'][i] =""

# %%
df_The_Plays_The_Thing_UK_2['Date'] = pd.to_datetime(df_The_Plays_The_Thing_UK_2['Date'])
df_The_Plays_The_Thing_UK_2['Date'] = pd.to_datetime(df_The_Plays_The_Thing_UK_2["Date"].dt.strftime('%Y-%m-%d'))
df_The_Plays_The_Thing_UK_2.head(3)
# Out:
#                 Newspaper                           Title          Theatre  \
# 0  The Plays The Thing UK  When the Sea Swallows Us Whole   VAULT Festival
# 1  The Plays The Thing UK                     On Arriving   VAULT Festival
# 2  The Plays The Thing UK                          Gorgon   VAULT Festival
#
#            Reviewer       Date    Reviewer.1  \
# 0   by Dora Bodrogi 2020-02-06  laurakressly
# 1    by Emma Lamond 2020-02-07  laurakressly
# 2  by Verity Sharpe 2020-02-10  laurakressly
#
#                                             Keywords  \
# 0  climate change,family,friendship,growing up,LG...
# 1  immigration,new writing,political issues,refug...
# 2  foley,horror,new writing,review,sound,storytel...
#
#                                               Review
# 0  Climate, sexuality, religion, growing up, frie...
# 1  This play is a confronting and heartbreaking w...
# 2  This is a spectacularly brilliant show which f...

# %%
df_View_From_The_Cheap_Seat_2['Date'] = df_View_From_The_Cheap_Seat_2['Date'].replace(" Old Red Lion Pub Theatre","")
df_View_From_The_Cheap_Seat_2['Date'] = df_View_From_The_Cheap_Seat_2['Date'].replace(" Leicester Square Theatre","")
df_View_From_The_Cheap_Seat_2['Date'] = pd.to_datetime(df_View_From_The_Cheap_Seat_2['Date'])
df_View_From_The_Cheap_Seat_2['Date'] = pd.to_datetime(df_View_From_The_Cheap_Seat_2["Date"].dt.strftime('%Y-%m-%d'))
df_View_From_The_Cheap_Seat_2.head(3)
# Out:
#                   Newspaper                Title                     Theatre  \
# 0  View From The Cheap Seat            Stay Safe                    Whatsapp
# 1  View From The Cheap Seat  Next Thing You Know   Garden Theatre @Eagle Pub
# 2  View From The Cheap Seat              Eye Say                     Eye Say
#
#         Date         Reviewer  \
# 0 2020-10-30   Shanine Salmon
# 1 2020-10-27  naomiwesterman1
# 2 2020-10-18       Alex Finch
#
#                                               Review
# 0  Whatspp? Yes, New Perspective's haunting new p...
# 1  Forgive me for taking the scenic route to star...
# 2  Eye Say, Eye Say, Eye Say' brought together th...

# %%
df_West_End_Whingers_2['Date'] = pd.to_datetime(df_West_End_Whingers_2['Date'])
df_West_End_Whingers_2['Date'] = pd.to_datetime(df_West_End_Whingers_2["Date"].dt.strftime('%Y-%m-%d'))
df_West_End_Whingers_2.head(3)
# Out:
#            Newspaper       Date Reviewer  \
# 0  West End Winghers 2012-04-30     Phil
# 1  West End Winghers 2012-09-11     Phil
# 2  West End Winghers 2008-05-18     Phil
#
#                                      Title                Theatre Rating  \
# 0       South Downs / The Browning Version  Harold Pinter Theatre  ★★★★★
# 1                               Steel Pier          Union Theatre    ★★★
# 2  That Face at the Duke of York’s Theatre                    NaN    NaN
#
#                                               Review
# 0  \nOne Man’s Two Guvnors may be another man’s p...
# 1  \nSPOILERS. Imagine They Shoot Horses, Don’t T...
# 2  The Whingers are feeling a tad existential tod...

# %%
df_West_End_Wilma_2['Date'] = pd.to_datetime(df_West_End_Wilma_2['Date'])
df_West_End_Wilma_2['Date'] = pd.to_datetime(df_West_End_Wilma_2["Date"].dt.strftime('%Y-%m-%d'))
df_West_End_Wilma_2.head(3)
# Out:
#         Newspaper       Date         Reviewer  \
# 0  WEST END WILMA 2020-03-26       Emma Heath
# 1  WEST END WILMA 2020-03-12   West End Wilma
# 2  WEST END WILMA 2020-02-24       Emma Heath
#
#                                 Title                        Theatre  \
# 0                    LOVE, LOVE, LOVE          the Lyric Hammersmith
# 1  Irish Play ON BLUEBERRY HILL opens    Trafalgar Studios exploring
# 2                  La Cage aux Folles  Park Theatre - West End Wilma
#
#                                               Rating  \
# 0                                                 ★★
# 1  ★★★★\nReviewed by West End Wilma\nPhoto: Marc ...
# 2                                                ★★★
#
#                                               Review
# 0  Written by Mike Bartlett, Love, Love, Love ser...
# 1  \nSebastian Barry‘s 2017 production of On Blue...
# 2  Too much farce and not enough affection in thi...

# %%
display(df_A_Younger_Theatre_Off_West_End_2.head(3))# Newspaper
display(df_A_Younger_Theatre_West_End_2.head(3))# Newspaper
display(df_Everything_Theatre_2.head(3))# Newspaper
display(df_Lou_Review_2.head(3))
display(df_Monkey_Matters_2.head(3))
display(df_Ought_To_Be_Clowns_2.head(3))# Newspaper
display(df_Pocket_Size_Theatre_2.head(3))# Newspaper
display(df_The_Blog_Of_Theatre_Thing_2.head(3))
display(df_The_Exeunt_2.head(3))# Newspaper
display(df_The_Plays_The_Thing_UK_2.head(3))
display(df_View_From_The_Cheap_Seat_2.head(3))
display(df_West_End_Whingers_2.head(3))# Newspaper
display(df_West_End_Wilma_2.head(3))# Newspaper
# Out:
#            Newspaper        Date           Reviewer                 Title  \
# 0  A YOUNGER THEATER  11/12/2020  Jessica Handscomb       The Dumb Waiter
# 1  A YOUNGER THEATER  10/12/2020  Jessica Handscomb              Mr Stink
# 2  A YOUNGER THEATER  08/12/2020       Olivia Kiely  The Gruffalo’s Child
#
#                                     Theatre Rating  \
# 0  Hampstead Theatre" property="og:title"/>   ★★★★
# 1                       Chickenshed Theatre    ★★★
# 2                              Tall Stories    ★★★
#
#                                             Keywords  \
# 0  Alec Newman,Alice Hamilton,Harold Pinter,James...
# 1  Belinda McGuirk,Bethany Hamlin,Bradley Davis,C...
# 2  Alexandra Palace,Althea Burey,Andy Shaw,Axel S...
#
#                                               Review
# 0  \nI think it’s fair to say that 2020 has been ...
# 1  \nDavid Walliams is not my favourite children’...
# 2  \nIt is fair to say that I’m a bit older than ...
# ...

# %%
df_final_corpus_2 = pd.concat([df_A_Younger_Theatre_Off_West_End_2,df_A_Younger_Theatre_West_End_2,df_Everything_Theatre_2,df_Lou_Review_2,df_Monkey_Matters_2,df_Ought_To_Be_Clowns_2,df_Pocket_Size_Theatre_2,df_The_Blog_Of_Theatre_Thing_2,df_The_Exeunt_2,df_The_Plays_The_Thing_UK_2,df_View_From_The_Cheap_Seat_2,df_West_End_Whingers_2,df_West_End_Wilma_2], ignore_index = True)
df_final_corpus_2.head(3)
# Out:
#            Newspaper        Date           Reviewer                 Title  \
# 0  A YOUNGER THEATER  11/12/2020  Jessica Handscomb       The Dumb Waiter
# 1  A YOUNGER THEATER  10/12/2020  Jessica Handscomb              Mr Stink
# 2  A YOUNGER THEATER  08/12/2020       Olivia Kiely  The Gruffalo’s Child
#
#                                     Theatre Rating  \
# 0  Hampstead Theatre" property="og:title"/>   ★★★★
# 1                       Chickenshed Theatre    ★★★
# 2                              Tall Stories    ★★★
#
#                                             Keywords  \
# 0  Alec Newman,Alice Hamilton,Harold Pinter,James...
# 1  Belinda McGuirk,Bethany Hamlin,Bradley Davis,C...
# 2  Alexandra Palace,Althea Burey,Andy Shaw,Axel S...
#
#                                               Review Author Opening Closing  \
# 0  \nI think it’s fair to say that 2020 has been ...    NaN     NaN     NaN
# 1  \nDavid Walliams is not my favourite children’...    NaN     NaN     NaN
# ...

# %%
df_final_corpus_2.notna().sum()/len(df_final_corpus_2)*100
# Out:
# Newspaper     100.000000
# Date           99.302795
# Reviewer       95.849352
# Title          99.719815
# Theatre        81.116831
# Rating         29.497622
# Keywords       38.209422
# Review         99.354923
# Author         17.058709
# Opening        18.857106
# Closing        18.857106
# Director       18.694207
# Categories      6.672314
# Theatre         3.531635
# Reviewer.1      8.125367
# dtype: float64

# %%
df_final_corpus_2_v2 = df_final_corpus_2.copy()
df_final_corpus_2_v2 = df_final_corpus_2_v2[['Newspaper','Date','Reviewer','Title','Theatre','Rating','Review']]
display(df_final_corpus_2_v2.head(3))
display(df_final_corpus_2_v2.shape)
# Out:
#            Newspaper        Date           Reviewer                 Title  \
# 0  A YOUNGER THEATER  11/12/2020  Jessica Handscomb       The Dumb Waiter
# 1  A YOUNGER THEATER  10/12/2020  Jessica Handscomb              Mr Stink
# 2  A YOUNGER THEATER  08/12/2020       Olivia Kiely  The Gruffalo’s Child
#
#                                     Theatre Rating  \
# 0  Hampstead Theatre" property="og:title"/>   ★★★★
# 1                       Chickenshed Theatre    ★★★
# 2                              Tall Stories    ★★★
#
#                                               Review
# 0  \nI think it’s fair to say that 2020 has been ...
# 1  \nDavid Walliams is not my favourite children’...
# 2  \nIt is fair to say that I’m a bit older than ...
# (15347, 7)

# %%
# work on date
# remove and clean
# replace nonsense with NA

# %%
df_final_corpus_2_v2.to_excel("20201221_Corpus_II_v1.xlsx")
# Out:
# /Users/gaetanbrison/opt/anaconda3/lib/python3.7/site-packages/xlsxwriter/worksheet.py:937: UserWarning: Ignoring URL 'https://www.youtube.com/watch?v=IxK2D0RbrBo
# ,%20Fraaaank%20Norman%20first%20wrote%20“Bang%20to%20Rights”
# ,%20“Fings”%20set%20the%20West%20End%20alight
# ,%20Theatre%20ain’t%20what%20it%20used%20to%20be.%201
# ,%20Babs%20ain’t%20on%20the%20stage%20no%20more
# ,%20‘Stead%20she’s%20loungin’%20in%20the%20stalls%202
# ,%20Watchin’%20some%20pal%20from%20Albert%20Square.%203
# ,%20It’s%20set%20in%20a%20club!%20Not%20very%20posh
# ,%20Full%20of%20card%20sharps%20and%20pimps
# ,%20But%20now%20they’ve%20got%20dosh,%20won%20on%20the%20pools,
# ,%20They’re%20planning…
# ,%20No%20more%20thrills%20and%20spilling
# ,%20This%20joint%20will%20make%20a%20killing
# ,%20But%20fings%20ain’t%20what%20they%20used%20to%20be
# ,%20They%20hire%20a%20problematic%20“poof”4
# ,%20Tart%20it%20up%20from%20floor%20to%20roof,
# ,%20Fings%20still%20ain’t%20what%20they%20ought%20to%20be
# ,%20%20
# ...
